# %%
import pandas as pd
import numpy as np
import datetime
import math

# %%
inp = pd.read_parquet('/Users/angad/Downloads/BTC-USDT.parquet',engine = 'pyarrow')
inp.reset_index(level=0,inplace=True)
inp.shape
# Out:
# (1828151, 10)

# %%
#Keep the important columns only
df = inp[['open_time','open','high','low','close','volume']]

# %%
#Start from 0:0:0 on 18th Aug 2017, rmeove partial data of 17th Aug 2017
df = df[df['open_time']>=datetime.datetime(2017,8,18,0,0)]
df.reset_index(inplace =True,drop=True)
df.shape
# Out:
# (1826951, 6)

# %%
df.head(30)
# Out:
#              open_time         open         high          low        close  \
# 0  2017-08-18 00:00:00  4285.080078  4285.080078  4285.080078  4285.080078
# 1  2017-08-18 00:01:00  4285.080078  4285.080078  4285.080078  4285.080078
# 2  2017-08-18 00:02:00  4285.080078  4285.080078  4285.080078  4285.080078
# 3  2017-08-18 00:03:00  4285.080078  4287.089844  4285.080078  4287.089844
# 4  2017-08-18 00:04:00  4287.089844  4287.089844  4287.089844  4287.089844
# 5  2017-08-18 00:05:00  4267.779785  4290.569824  4267.779785  4290.569824
# 6  2017-08-18 00:06:00  4290.569824  4290.569824  4290.569824  4290.569824
# 7  2017-08-18 00:07:00  4290.569824  4290.569824  4290.569824  4290.569824
# 8  2017-08-18 00:08:00  4290.569824  4292.100098  4290.569824  4292.100098
# 9  2017-08-18 00:09:00  4292.100098  4292.100098  4292.100098  4292.100098
# 10 2017-08-18 00:10:00  4305.759766  4305.759766  4305.759766  4305.759766
# 11 2017-08-18 00:11:00  4305.759766  4305.759766  4305.759766  4305.759766
# 12 2017-08-18 00:12:00  4304.759766  4305.750000  4304.759766  4305.750000
# 13 2017-08-18 00:13:00  4305.759766  4305.759766  4305.759766  4305.759766
# 14 2017-08-18 00:14:00  4305.759766  4305.759766  4305.759766  4305.759766
# 15 2017-08-18 00:15:00  4309.080078  4309.080078  4309.080078  4309.080078
# 16 2017-08-18 00:16:00  4289.529785  4309.080078  4289.529785  4302.149902
# 17 2017-08-18 00:17:00  4302.149902  4302.149902  4302.149902  4302.149902
# 18 2017-08-18 00:18:00  4303.830078  4303.830078  4302.149902  4303.830078
# 19 2017-08-18 00:19:00  4303.830078  4303.830078  4303.830078  4303.830078
# 20 2017-08-18 00:20:00  4303.830078  4303.830078  4303.830078  4303.830078
# 21 2017-08-18 00:21:00  4303.830078  4303.830078  4303.830078  4303.830078
# 22 2017-08-18 00:22:00  4303.830078  4303.830078  4303.830078  4303.830078
# 23 2017-08-18 00:23:00  4303.830078  4303.830078  4303.830078  4303.830078
# 24 2017-08-18 00:24:00  4285.850098  4303.830078  4285.850098  4303.830078
# 25 2017-08-18 00:25:00  4309.919922  4309.919922  4304.490234  4304.490234
# 26 2017-08-18 00:26:00  4304.490234  4304.490234  4304.490234  4304.490234
# 27 2017-08-18 00:27:00  4304.490234  4304.490234  4304.490234  4304.490234
# 28 2017-08-18 00:28:00  4304.490234  4304.490234  4304.490234  4304.490234
# 29 2017-08-18 00:29:00  4292.109863  4292.109863  4292.109863  4292.109863
#
#       volume
# 0   0.022196
# 1   0.463420
# 2   0.215048
# 3   0.926866
# 4   1.335457
# 5   3.928621
# 6   0.519288
# 7   0.665807
# 8   0.406305
# 9   0.000000
# 10  0.165819
# 11  0.388614
# 12  1.042320
# 13  0.378726
# 14  0.000000
# 15  0.028756
# 16  4.292810
# 17  2.475285
# 18  0.365220
# 19  0.000000
# 20  0.377514
# 21  0.000000
# 22  0.366999
# 23  0.625428
# 24  4.475604
# 25  0.971997
# 26  0.476150
# 27  0.861994
# 28  0.000000
# 29  0.595227

# %%
#Prepare data for different timeframe candles

def convert_min_hr_day(str):
    last_char = str[-1]
    rem_char = int(str[:-1])
    
    if last_char =='m':
        time_unit = 1*rem_char
    elif last_char == 'h':
        time_unit = 60*rem_char
    elif last_char == 'd':
        time_unit = 24*60*rem_char
    else:
        time_unit=0
    print("time_unit:",time_unit)
    return time_unit

# %%
def prepare_data(df,time):
    row_count = df.shape[0]
    time_unit = convert_min_hr_day(time)
    no_of_levels = math.ceil(row_count/time_unit)
    levels_list = list(range(1,no_of_levels+1))
    levels_list_expand = sorted(levels_list*time_unit)
    group_final_list = levels_list_expand[:row_count]
    
    df2 = df.copy()
    df2.insert(0,'group',group_final_list)
    
    output = pd.DataFrame()
    
    output['open'] = df2.groupby(['group']).first().open
    output['high'] = df2.groupby(['group'])['high'].max()
    output['low'] = df2.groupby(['group'])['low'].min()
    output['close'] = df2.groupby(['group']).last().close
    output['volume'] = df2.groupby(['group'])['volume'].sum()
    output['date'] = df2.groupby(['group']).first().open_time
    output['date'] = pd.to_datetime(output['date'])
    #output['date'] = output['date'].dt.date
    output.index= output['date']
    
    
    
    print('output_shape:',output.shape)
    return output

# %%
output = prepare_data(df,'15d')
# Out:
# time_unit: 21600
# output_shape: (85, 6)

# %%
output.head(10)
# Out:
#                                  open          high           low  \
# date
# 2017-08-18 00:00:00.000   4285.080078   4885.549805   3400.000000
# 2017-09-02 00:00:00.000   4834.910156   4939.189941   2817.000000
# 2017-09-17 07:01:00.000   3563.050049   4560.000000   3499.020020
# 2017-10-02 07:01:00.000   4452.870117   5922.299805   4110.000000
# 2017-10-17 07:01:00.000   5640.140137   6498.009766   5037.950195
# 2017-11-01 07:01:00.000   6414.819824   7770.020020   5325.009766
# 2017-11-16 07:01:00.000   7283.419922  11300.030273   7250.060059
# 2017-12-01 07:01:00.000   9431.030273  17991.000000   9380.000000
# 2017-12-16 07:01:20.799  17625.650391  19798.679688  10961.000000
# 2017-12-31 08:20:00.000  12707.559570  17176.240234  11400.000000
#
#                                 close         volume                    date
# date
# 2017-08-18 00:00:00.000   4834.910156    9781.156250 2017-08-18 00:00:00.000
# 2017-09-02 00:00:00.000   3563.050049   15615.473633 2017-09-02 00:00:00.000
# 2017-09-17 07:01:00.000   4452.870117   12384.630859 2017-09-17 07:01:00.000
# 2017-10-02 07:01:00.000   5640.140137   14366.750000 2017-10-02 07:01:00.000
# 2017-10-17 07:01:00.000   6415.000000   26682.109375 2017-10-17 07:01:00.000
# 2017-11-01 07:01:00.000   7283.419922   33249.980469 2017-11-01 07:01:00.000
# 2017-11-16 07:01:00.000   9435.990234   76445.593750 2017-11-16 07:01:00.000
# 2017-12-01 07:01:00.000  17625.650391  142968.046875 2017-12-01 07:01:00.000
# 2017-12-16 07:01:20.799  12707.230469  256789.375000 2017-12-16 07:01:20.799
# 2017-12-31 08:20:00.000  13660.959961  270516.437500 2017-12-31 08:20:00.000

# %% [markdown]
# # Candlestick plot using matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Loading data into dataframe:

# Converting the dates from string to datetime format:
output.index = pd.to_datetime(output.index)

# We need to exctract the OHLC prices into a list of lists:
dvalues = output[['open', 'high', 'low', 'close']].values.tolist()

# Dates in our index column are in datetime format, we need to comvert them 
# to Matplotlib date format (see https://matplotlib.org/3.1.1/api/dates_api.html):
pdates = mdates.date2num(output.index)

# If dates in our index column are strings instead of datetime objects, we should use:
# pdates = mpl.dates.datestr2num(data.index)

# We prepare a list of lists where each single list is a [date, open, high, low, close] sequence:
ohlc = [ [pdates[i]] + dvalues[i] for i in range(len(pdates)) ]

# %%
import mpl_finance as mpf # This is the old mpl-finance library - note the '_' in the library name

# We can now feed the ohlc matrix into mpl-finance to create a candle stick chart:

#plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(figsize = (12,6))

mpf.candlestick_ohlc(ax, ohlc[-50:-10], width=5,colorup='g',colordown='r')
ax.set_xlabel('Date')
ax.set_ylabel('Price ($)')
ax.set_title('SPDR S&P 500 ETF Trust - Candlestick Chart')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

fig.autofmt_xdate()

# plt.show() # add this if you're not using Jupyter Notebook
# Out:
# /Users/angad/opt/anaconda3/lib/python3.8/site-packages/mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
# !brew install ta-lib
# Out:
# Updating Homebrew...
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# atuin               imath               oksh                sysstat
# autorestic          ipinfo-cli          openexr@2           trojan-go
# cadical             julia               openj9              tssh
# clazy               ki                  pgxnclient          virtualenvwrapper
# ddcctl              lm-sensors          qodem               xfig
# elan-init           lsix                rmw                 zellij
# gcc@10              mathlibtools        scotch
# gtksourceview5      nox                 search-that-hash
# ==> Updated Formulae
# Updated 1002 formulae.
# ==> Deleted Formulae
# aurora-cli          erlang@20           protobuf-swift      protobuf@3.7
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/ta-lib/manifests/0.4.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ta-lib/blobs/sha256:363867dbdc2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Pouring ta-lib--0.4.0.big_sur.bottle.1.tar.gz
# 🍺  /usr/local/Cellar/ta-lib/0.4.0: 15 files, 2.4MB

# %%
# !pip install TA-Lib
# Out:
# Collecting TA-Lib
#   Using cached TA-Lib-0.4.19.tar.gz (267 kB)
# Requirement already satisfied: numpy in /Users/angad/opt/anaconda3/lib/python3.8/site-packages (from TA-Lib) (1.20.1)
# Building wheels for collected packages: TA-Lib
#   Building wheel for TA-Lib (setup.py) ... done
#   Created wheel for TA-Lib: filename=TA_Lib-0.4.19-cp38-cp38-macosx_10_9_x86_64.whl size=433238 sha256=1bdfa7b5e4c0def70c0542e76c167dfa263eafefd5a0044e186d0a6eb5dfdfd5
#   Stored in directory: /Users/angad/Library/Caches/pip/wheels/01/25/3f/e5d103f2658231d822d0fc879d2aa07eb178b21471dab9662a
# Successfully built TA-Lib
# Installing collected packages: TA-Lib
# Successfully installed TA-Lib-0.4.19

# %%
#Define the RSI
import talib
output["rsi"] = talib.RSI(output["close"])

# %%
#DEFINE THE RANGE OF DATA HERE
#Taking -100 to -10 range
output_cp = output.copy()[-100:]
ohlc_cp = ohlc[-100:]

# %%
hsma40 = output_cp['high'].rolling(10).mean()
lsma40 = output_cp['low'].rolling(10).mean()

#exponential moving average
ema10 = output_cp['close'].ewm(span=10).mean()
ema20 = output_cp['close'].ewm(span=20).mean()

#bollinger band
output_cp['TP'] = (output_cp['close'] + output_cp['low'] + output_cp['high'])/3
output_cp['std'] = output_cp['TP'].rolling(20).std(ddof=0)
output_cp['MA-TP'] = output_cp['TP'].rolling(20).mean()
output_cp['BOLU'] = output_cp['MA-TP'] + 2*output_cp['std']
output_cp['BOLD'] = output_cp['MA-TP'] - 2*output_cp['std']

#fig, ax = plt.subplots(figsize = (12,6))

fig = plt.figure()
fig.set_size_inches((20,16 ))
ax_candle = fig.add_axes((0, 0.67, 1, 0.52))
#ax_macd = fig.add_axes((0, 0.48, 1, 0.2), sharex=ax_candle)
ax_rsi = fig.add_axes((0, 0.32, 1, 0.3), sharex=ax_candle)
ax_vol = fig.add_axes((0, 0, 1, 0.3), sharex=ax_candle)

mpf.candlestick_ohlc(ax_candle, ohlc_cp, width = 5,colorup='#77d879', colordown='#db3f3f')
ax_candle.plot(hsma40, color = 'blue', linewidth = 1, label='High, 10-Day SMA')
ax_candle.plot(lsma40, color = 'blue', linewidth = 1, label='Low, 10-Day SMA')

ax_candle.plot(ema10, color = 'red', linestyle='--', linewidth = 2, label='Close, 10-Day EMA')
ax_candle.plot(ema20, color = 'pink', linestyle='--', linewidth = 2, label='Close, 20-Day EMA')

ax_candle.plot(output_cp['close'],color ='cadetblue',label = 'Close')
ax_candle.plot(output_cp['BOLU'],color ='slategrey',label = 'Bollinger Band - UP')
ax_candle.plot(output_cp['BOLD'],color ='rosybrown',label = 'Bollinger Band - Down')
ax_candle.fill_between(output_cp.index, output_cp['BOLD'], output_cp['BOLU'], facecolor='orange', alpha=0.1)


ax_candle.set_xlabel('Date')
ax_candle.set_ylabel('Price ($)')
ax_candle.set_title('SPDR S&P 500 ETF Trust - Bar Chart with Moving Averages')
ax_candle.legend()
ax_candle.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))




# Plot RSI
# Above 70% = overbought, below 30% = oversold
ax_rsi.set_ylabel("(%)")
ax_rsi.plot(output_cp.index, [70] * len(output_cp.index), label="overbought")
ax_rsi.plot(output_cp.index, [30] * len(output_cp.index), label="oversold")
ax_rsi.plot(output_cp.index, output_cp["rsi"], label="rsi")
ax_rsi.legend()



# Show volume in millions
ax_vol.bar(output_cp.index, output_cp["volume"] / 1000)
ax_vol.set_ylabel("(Thousand)")






fig.autofmt_xdate()
plt.show()

# %%
boll = output.copy()
boll['TP'] = (boll['close'] + boll['low'] + boll['high'])/3
boll['std'] = boll['TP'].rolling(20).std(ddof=0)
boll['MA-TP'] = boll['TP'].rolling(20).mean()
boll['BOLU'] = boll['MA-TP'] + 2*boll['std']
boll['BOLD'] = boll['MA-TP'] - 2*boll['std']

# %%
ax = boll[['close', 'BOLU', 'BOLD']].plot(color=['blue', 'orange', 'yellow'])
ax.fill_between(boll.index, boll['BOLD'], boll['BOLU'], facecolor='orange', alpha=0.1)
plt.show()

# %% [markdown]
# import mplfinance as fplt

# %% [markdown]
# fplt.plot(
#             output,
#             type='candle',
#             style='charles',
#
#             title='Candlestick chart for BTC-USDT',
#             ylabel='Price ($)',
#             volume=True,
#             mav = 2,
#             #savefig = 'plot.png'
#         )

# %% [markdown]
# import plotly.graph_objects as go
#
# candlestick = go.Candlestick(
#                             x=output.index,
#                             open=output['open'],
#                             high=output['high'],
#                             low=output['low'],
#                             close=output['close']
#                             )
#
# fig = go.Figure(data=[candlestick])
#
# fig.show()

# %% [markdown]
# import cufflinks as cf
# cf.set_config_file(theme='pearl',sharing='public',offline=True)

# %% [markdown]
# output.iplot(kind="candle",
#                           keys=["open", "high", "low", "close"],
#                           rangeslider=True
#                           )

# %% [markdown]
# #apple_df = pd.read_csv('/datasets/AAPL.csv', index_col=0, parse_dates=True)
#
# qf=cf.QuantFig(output,title='BTC-USDT data',legend='top',name='plot')
#
# qf.add_bollinger_bands()
# qf.add_volume()
# #qf.add_resistance(date = '2018-03-17')
# #qf.add_support(date = '2018-03-17')
# #qf.add_trendline(date0 = '2017-11-15',date1 ='2020-12-04',text ='Trend')
# #qf.add_volume()
#
# fig, ax = plt.subplots()
# qf.iplot()
# date_format = mpl_dates.DateFormatter('%d %b %Y')
# ax.xaxis.set_major_formatter(date_format)
# fig.autofmt_xdate()
# fig.tight_layout()
# for level in levels:
#     plt.hlines(level[1],xmin=output['date'][level[0]],\
#                xmax=max(output['date']),colors='blue')
# fig.show()
#
# # qf.iplot()

# %% [markdown]
# output

# %% [markdown]
# output['date'] = pd.to_datetime(output.index)
# output['date'] = output['date'].apply(mpl_dates.date2num)
#
# output = output.loc[:,['date', 'open', 'high', 'low', 'close']]

# %% [markdown]
# output.head()

# %% [markdown]
# import os
# os.system('say "Vaccine slot found"')

# %% [markdown]
# os.system('beep -f %s -l %s' % (1000, 2000))

# %% [markdown]
# #!pip install yfinance
# !pip install mplfinance

# %% [markdown]
# import pandas as pd
# import numpy as np
# import yfinance
# from mpl_finance import candlestick_ohlc
# %matplotlib inline
#
# import matplotlib.dates as mpl_dates
#
# import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [12, 7]
# plt.rc('font', size=14)

# %% [markdown]
# output.head()

# %%
output['date'] =pd.to_datetime(output['date'])
output['date'] = output['date'].dt.date
output.head()
# Out:
#                            date         open         high          low  \
# date
# 2017-08-18 00:00:00  1970-01-01  4285.080078  4885.549805  3400.000000
# 2017-09-02 00:00:00  1970-01-01  4834.910156  4939.189941  2817.000000
# 2017-09-17 07:01:00  1970-01-01  3563.050049  4560.000000  3499.020020
# 2017-10-02 07:01:00  1970-01-01  4452.870117  5922.299805  4110.000000
# 2017-10-17 07:01:00  1970-01-01  5640.140137  6498.009766  5037.950195
#
#                            close
# date
# 2017-08-18 00:00:00  4834.910156
# 2017-09-02 00:00:00  3563.050049
# 2017-09-17 07:01:00  4452.870117
# 2017-10-02 07:01:00  5640.140137
# 2017-10-17 07:01:00  6415.000000

# %% [markdown]
# def isSupport(df,i):
#   support = df['low'][i] < df['low'][i-1]  and df['low'][i] < df['low'][i+1] and df['low'][i+1] < df['low'][i+2] and df['low'][i-1] < df['low'][i-2]
#   return support
# def isResistance(df,i):
#   resistance = df['high'][i] > df['high'][i-1]  and df['high'][i] > df['high'][i+1] and df['high'][i+1] > df['high'][i+2] and df['high'][i-1] > df['high'][i-2]
#   return resistance

# %% [markdown]
# levels = []
# for i in range(2,output.shape[0]-2):
#   if isSupport(output,i):
#     levels.append((i,output['low'][i]))
#   elif isResistance(output,i):
#     levels.append((i,output['high'][i]))

# %% [markdown]
# def plot_all():
#   fig, ax = plt.subplots()
#
#   candlestick_ohlc(ax,output.values,width=0.6, \
#                    colorup='green', colordown='red', alpha=0.8)
#
#   date_format = mpl_dates.DateFormatter('%d %b %Y')
#   ax.xaxis.set_major_formatter(date_format)
#   fig.autofmt_xdate()
#
#   fig.tight_layout()
#
#   for level in levels:
#     plt.hlines(level[1],xmin=output['date'][level[0]],\
#                xmax=max(output['date']),colors='blue')
#   #fig.show()

# %% [markdown]
# plot_all()

# %% [markdown]
# levels
